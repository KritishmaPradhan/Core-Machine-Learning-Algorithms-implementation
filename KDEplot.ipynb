# %%
# Kernel Density Estimate plot using random dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import randn
# %matplotlib inline

# %%
plotData = pd.DataFrame(randn(400,3), columns = ['Red', 'Blue', 'Green'])  # randn(rows,columns)
plotData
# Out:
#           Red      Blue     Green
# 0    1.132216 -1.140400 -0.356129
# 1   -0.762823 -0.476247  0.781061
# 2    1.229876 -0.973349 -0.040767
# 3   -1.564331 -0.184046  0.223865
# 4   -0.421451 -0.207924  1.179012
# ..        ...       ...       ...
# 395  0.297048 -0.263538  0.169139
# 396 -1.206867  0.444854 -0.148874
# 397  0.519193  0.423572 -1.226822
# 398 -0.627530  0.873070  0.812132
# 399 -1.978726 -2.440696 -1.505394
#
# [400 rows x 3 columns]

# %%
plotData.plot.kde()          # kde from scipy
plt.show()
